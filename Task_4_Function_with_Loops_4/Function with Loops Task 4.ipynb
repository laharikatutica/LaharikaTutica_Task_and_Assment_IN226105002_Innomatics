# %% [markdown]
# ## Problem 1: Mobile Recharge Validation System

# %% [markdown]
# Problem Statement
#
# Create a function to validate a mobile recharge request.
#
# Rules:
# Recharge amount must be ≥ ₹50
#
# Valid plans: 199, 299, 399, 599
#
# User should be allowed to retry if invalid
#
# Real-Time Use
#
# Telecom recharge apps
#
# Payment gateways
#
# Hint
# Use function for validation
#
# Use while loop for retry

# %%
#function to validate mobile recharge amount 
def mobile_recharge(amount):
    # Check if recharge amount is less than or equal to minimum allowed
    if amount<=50:
        return 'Recharge declined: Amount must be >=50'
        
    # Check if amount matches any valid recharge plan
    elif amount not in [199,299,399,599]:
        return 'Recharge declined: Enter a valid plan amount'

    # If all conditions are satisfied, recharge is successful
    return 'Recharge Successful!'

# Loop to allow user to retry until a valid recharge is entered
while True:
    #user input for recharge amount
    amount = int(input('Enter the recharge amount:'))
    #calling the mobile_recharge function
    result = mobile_recharge(amount)
    #display the result
    print(result)

    #Exit the loop if recharge is successful
    if result == 'Recharge Successful!':
        break
# Out:
# Enter the recharge amount: 49
# Recharge declined: Amount must be >=50
# Enter the recharge amount: 190
# Recharge declined: Enter a valid plan amount
# Enter the recharge amount: 299
# Recharge Successful!

# %% [markdown]
# ## Problem 2: Inventory Reorder Alert System

# %% [markdown]
# Problem Statement
#
# Given a dictionary of products and stock quantities:
#
# Print Reorder Alert if stock < 15
#
# Print Stock OK otherwise
#
# Real-Time Use
# Warehouse systems
#
# Retail management
#
#
# Hint
# Use function
#
#
# Use for loop on dictionary

# %%
# Creating a dictionary of products and their stock quantities
products = {}

# number of products
n = int(input("Enter number of products: "))

# Taking user input
for i in range(n):
    product = input(f"Enter product name{i+1}: ")
    stock = int(input("Enter stock quantity: "))
    products[product] = stock

# function to check stock levels
def check_stock(products):
    # iterating through each product in the dictionary
    for product, stock in products.items():
        #checking minimum stock quantity
        if stock < 15:
            print(product, ": Reorder Alert")
        else:
            print(product, ": Stock OK")

# Function call
check_stock(products)
# Out:
# Enter number of products:  4
# Enter product name1:  Rice
# Enter stock quantity:  20
# Enter product name2:  Oil
# Enter stock quantity:  10
# Enter product name3:  Salt
# Enter stock quantity:  13
# Enter product name4:  Flour
# Enter stock quantity:  19
# Rice : Stock OK
# Oil : Reorder Alert
# Salt : Reorder Alert
# Flour : Stock OK

# %% [markdown]
# ## Problem 3: Student Result Processing System

# %% [markdown]
# Problem Statement
#
# Create a function that:
#
# Accepts a list of student marks
#
# Calculates average marks
#
#
# Prints Pass if average ≥ 50 else Fail
#
#
# Real-Time Use:
#
# Online exam systems
#
# Evaluation portals
#
# Hint
# Use loop to calculate total
#
# Return result from function

# %%
# Function to calculate result based on average marks
def result(marks):
    total = 0
    # Calculate total marks using loop
    for mark in marks:
        total += mark

    #calculate average marks
    avg = total/len(marks)

    #checking pass or fail condition
    if avg >= 50:
        return 'Pass'
    else:
        return 'Fail'

#user input for number of subjects
n = int(input('Enter the number of subjects:'))

#empty list to store marks
student_marks = []

#taking user input for each subject marks
for i in range(n):
    m = int(input(f'Enter the marks of subject{i+1}: '))
    student_marks.append(m)

#function call
evaluate = result(student_marks)
print(evaluate)
# Out:
# Enter the number of subjects: 4
# Enter the marks of subject1:  49
# Enter the marks of subject2:  67
# Enter the marks of subject3:  82
# Enter the marks of subject4:  29
# Pass

# %% [markdown]
# ## Problem 4: Cab Fare Estimator with Retry Option

# %% [markdown]
# Problem Statement
#
# Create a cab fare calculator:
#
# Base fare = ₹50
#
# ₹12 per km
#
# Peak hour → 25% extra
#
# Allow retry using while loop
#
# Real-Time Use
#
# Ride-hailing apps
#
# Transport systems
#
# Hint
# Function for fare calculation
#
# While loop for retry

# %%
# Function to calculate cab fare
def cab_fare_estimate(kms,peak_hour):
    base_fare = 50
    price_per_km = 12

    # Calculate base fare + distance fare
    total_fare = base_fare + kms * 12

    # Add 25% extra during peak hours
    if peak_hour == 'yes':
        total_fare += total_fare*0.25

    return f'Your total fare estimate is ₹{total_fare}'

# Retry loop
while True:
    #user input for number of kms and peak_hour insights
    kms = int(input('Enter the number of kms: '))
    peak_hour = input('Is it a peak hour? (yes/no) ').lower()

    #function call
    estimate = cab_fare_estimate(kms,peak_hour)
    print(estimate)

    #retry option
    retry = input('Do you want to retry? (yes/no) ').lower()
    if retry != 'yes':
        break
# Out:
# Enter the number of kms:  10
# Is it a peak hour? (yes/no)  yes
# Your total fare estimate is ₹212.5
# Do you want to retry? (yes/no)  yes
# Enter the number of kms:  10
# Is it a peak hour? (yes/no)  no
# Your total fare estimate is ₹170
# Do you want to retry? (yes/no)  no

# %% [markdown]
# ## Problem 5: Employee Attendance Eligibility Checker

# %% [markdown]
# Problem Statement
#
# Create a function that:
#
# Accepts attendance list ("P", "A")
#
# Calculates attendance percentage
#
# Returns Eligible if ≥ 75% else Not Eligible
#
# Real-Time Use
#
# HR payroll systems
#
# Internship tracking
#
# Hint
# Use loop to count present days
#
# Use return statement

# %%
# Function to check attendance eligibility
def attendance_checker(attendance):
    p_count = 0
    
    # Count number of present days
    for attend in attendance:
        if attend == 'P':
            p_count += 1

    # Calculate attendance percentage
    at_percentage = p_count/len(attendance)*100

    # Check eligibility
    if at_percentage >= 75:
        return 'Eligible'
    else:
        return 'Not Eligible'

#user input for number of days
n = int(input('Enter the number of days:'))

#empty list to store attendance
attendance = []

#taking user input for each day
for i in range(n):
    while True:
        at = input(f'Enter the attendance on Day{i+1} (P or A): ').upper()
        if at in ['A','P']:
            attendance.append(at)
            break
        else:
            print('Invalid input for attendance')

#function call
eligibility = attendance_checker(attendance)
print(eligibility)
# Out:
# Enter the number of days: 5
# Enter the attendance on Day1 (P or A):  p
# Enter the attendance on Day2 (P or A):  s
# Invalid input for attendance
# Enter the attendance on Day2 (P or A):  p
# Enter the attendance on Day3 (P or A):  A
# Enter the attendance on Day4 (P or A):  P
# Enter the attendance on Day5 (P or A):  g
# Invalid input for attendance
# Enter the attendance on Day5 (P or A):  P
# Eligible

# %% [markdown]
# ## Problem 6: Password Strength Checker

# %% [markdown]
# Problem Statement
#
# Create a function to check password strength.
#
# Rules:
# Minimum length = 8
#
# Must contain at least one digit
#
# Must contain at least one special character (@#$)
#
# Real-Time Use
#
# Login systems
#
# Security validation
#
# Hint
#
# Use loop over string
#
# Use conditions inside function

# %%
# Function to check password strength
def password_checker(password):
    #checking minimum length
    if len(password) < 8:
        return 'Weak Password: minimum length must be 8 characters'

    has_digit = False
    has_special = False

    # Loop through each character in password
    for char in password: 
        if char.isdigit():
            has_digit= True
        if char in ['@','#','$']:
            has_special = True

    # Check digit condition
    if not has_digit:
        return 'Weak password: must contain atleast 1 digit'

    # Check special character condition
    if not has_special:
        return "Weak password: must contain atleast 1 special character (@#$)"
        
    # If all conditions are satisfied
    return "Approved! Strong Password"

#retry until strong password is entered
while True:
    #user input for password
    password = input('Enter your password: ')

    #function calling
    check = password_checker(password)
    print(check)

    if check == 'Approved! Strong Password':
        break
# Out:
# Enter your password:  laharika
# Weak password: must contain atleast 1 digit
# Enter your password:  laharika1
# Weak password: must contain atleast 1 special character (@#$)
# Enter your password:  lahar1@
# Weak Password: minimum length must be 8 characters
# Enter your password:  laharika@123
# Approved! Strong Password
